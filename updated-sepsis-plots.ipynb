# %%
from pandas import read_csv
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.style.use(u'fivethirtyeight')

# %% [markdown]
# # Outcomes and Metrics under the Sepsis Model

# %% [markdown]
# ### Import Outcomes and Metrics

# %%
dhm = read_csv('results/deceased_or_hospice_metrics.csv', index_col=0)
dho = read_csv('results/deceased_or_hospice_outcomes.csv', index_col=0)
sepm = read_csv('results/has_sepsis_metrics.csv', index_col=0)
sepo = read_csv('results/has_sepsis_outcomes.csv', index_col=0)

# %%
# dho.drop('false_negatives', axis=1, inplace=True)
# sepo.drop('false_negatives', axis=1, inplace=True)
# dhm.drop(['npv', 'sensitivity'], axis=1, inplace=True)
# sepm.drop(['npv', 'sensitivity'], axis=1, inplace=True)

# %% [markdown]
# ### Plot "deceased or hospice" metrics

# %%
# deceased_or_hospice_metrics
fig, ax = plt.subplots(1,1,figsize=(10,6))
dhm.plot(ax=ax)

# %% [markdown]
# ### "deceased or hospice" specificity

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dhm['specificity'].plot(ax=ax)

# %% [markdown]
# ### "deceased or hospice" sensitivity

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dhm['sensitivity'].plot(ax=ax)

# %% [markdown]
# ### "deceased or hospice" ppv

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dhm['ppv'].plot(ax=ax)

# %% [markdown]
# ### "deceased or hospice" npv

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dhm['npv'].plot(ax=ax)

# %% [markdown]
# ## Deceased or Hospice Outcomes

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dho.plot(ax=ax)

# %% [markdown]
# ### "Deceased or Hospice" false negatives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dho['false_negatives'].plot(ax=ax)

# %% [markdown]
# ### "Deceased or Hospice" false positives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dho['false_positives'].plot(ax=ax)

# %% [markdown]
# ### "Deceased or Hospice" True Positives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dho['true_positives'].plot(ax=ax)

# %% [markdown]
# ### "Deceased or Hospice" true negatives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
dho['true_negatives'].plot(ax=ax)

# %% [markdown]
# ## "Has Sepsis Code" metrics

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepm.plot(ax=ax)

# %% [markdown]
# ### "Has Sepsis Code" specificity

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepm.specificity.plot(ax=ax)

# %% [markdown]
# ### "Has Sepsis Code" sensitivity

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepm['sensitivity'].plot()

# %% [markdown]
# ### "Has Sepsis Code" ppv

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepm['ppv'].plot(ax=ax)

# %% [markdown]
# ## "Has Sepsis" Outcomes

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepo.plot(ax=ax)

# %% [markdown]
# ### "Has Sepsis" false positives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepo['false_positives'].plot(ax=ax)

# %% [markdown]
# ### "Has Sepsis" false negatives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepo.false_negatives.plot(ax=ax)

# %% [markdown]
# ### "Has Sepsis" true positives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepo.true_positives.plot(ax=ax)

# %% [markdown]
# ### "Has Sepsis" true negatives

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
sepo.true_negatives.plot(ax=ax)
